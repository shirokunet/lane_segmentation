# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import os
import random

# %%
def show_image(i, img, cmap=None):
    if i == 0:
        fig=plt.figure(figsize=(15,10))
    plt.subplot(8, 8, i+1)
    plt.tick_params(labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    plt.tick_params(bottom=False, left=False, right=False, top=False)
    plt.imshow(img, cmap=cmap)

# %% [markdown]
# # TuSimple Dataset

# %%
path = 'data/training_data_tusimple/train/gt_image'
files = os.listdir(path)
print(len(files), 'images')
# Out:
# 3626 images

# %%
for i in range(64):
    index = random.randrange(0, len(files))
    img_path = path + '/' + files[index]
    img = mpimg.imread(img_path)
    show_image(i, img)

# %% [markdown]
# # BDD100K Dataset

# %%
path = 'bdd100k/images/100k/train'
files = os.listdir(path)
print(len(files), 'images')
# Out:
# 70000 images

# %%
for i in range(64):
    index = random.randrange(0, len(files))
    img_path = path + '/' + files[index]
    img = mpimg.imread(img_path)
    show_image(i, img)

# %% [markdown]
# # BDD100K Dataset selected highway seans

# %%
path = 'bdd100k/images/100k_train/gt_image_jpg'
files = os.listdir(path)
print(len(files), 'images')
# Out:
# 10460 images

# %%
for i in range(64):
    index = random.randrange(0, len(files))
    img_path = path + '/' + files[index]
    img = mpimg.imread(img_path)
    show_image(i, img)
