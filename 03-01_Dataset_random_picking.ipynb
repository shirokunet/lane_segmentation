# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import os
import random

# %%
def show_image(i, img, cmap=None):
    if i == 0:
        fig=plt.figure(figsize=(15,10))
    plt.subplot(8, 8, i+1)
    plt.tick_params(labelbottom=False, labelleft=False, labelright=False, labeltop=False)
    plt.tick_params(bottom=False, left=False, right=False, top=False)
    plt.imshow(img, cmap=cmap)

# %% [markdown]
# # TuSimple Dataset

# %%
path = 'data/training_data_tusimple/train/gt_image'
files = os.listdir(path)
print(len(files), 'images')
# Out:
# 3626 images

# %%
for i in range(64):
    index = random.randrange(0, len(files))
    img_path = path + '/' + files[index]
    img = mpimg.imread(img_path)
    show_image(i, img)

# %% [markdown]
# # TuSimple Dataset gamma 0.4

# %%
path = 'data/training_data_tusimple/train/gt_image_gamma_0d4'
files = os.listdir(path)
print(len(files), 'images')
# Out:
# 3626 images

# %%
for i in range(64):
    index = random.randrange(0, len(files))
    img_path = path + '/' + files[index]
    img = mpimg.imread(img_path)
    show_image(i, img)
